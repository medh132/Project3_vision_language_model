# %%
# Code Cell 1
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# Code Cell 2
import os

print(os.path.isdir("/content/drive/MyDrive/AI504/"))
print(os.path.isfile("/content/drive/MyDrive/AI504/instruct_tuning.zip"))
# Change to your stduen ID
print(os.path.isfile("/content/drive/MyDrive/AI504/20233980.py"))
# Out:
# True
# True
# True

# %%
# Code Cell 3
import shutil

# When re-running the code, this code deletes "instruct_tuning" folder and then unzip again
folder_path = '/content/drive/MyDrive/AI504/instruct_tuning'

if os.path.exists(folder_path) and os.path.isdir(folder_path):
    shutil.rmtree(folder_path)


# !mkdir /content/drive/MyDrive/AI504/instruct_tuning
# !unzip /content/drive/MyDrive/AI504/instruct_tuning.zip -d /content/drive/MyDrive/AI504/instruct_tuning
# Out:
# Archive:  /content/drive/MyDrive/AI504/instruct_tuning.zip
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/instruct.json
#    creating: /content/drive/MyDrive/AI504/instruct_tuning/images/
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000539376.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000548061.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000387333.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000022827.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000123473.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000347981.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000123456.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000367233.jpg
#   inflating: /content/drive/MyDrive/AI504/instruct_tuning/images/000000399937.jpg
# ...

# %%
# Code Cell 4
import os
import shutil

def count_files_in_directory(directory_path):
    with os.scandir(directory_path) as entries:
        return sum(1 for entry in entries if entry.is_file())

directory_path = '/content/drive/MyDrive/AI504/instruct_tuning/images'
file_count = count_files_in_directory(directory_path)
print(f"There are {file_count} files in {directory_path}")
# Out:
# There are 1020 files in /content/drive/MyDrive/AI504/instruct_tuning/images

# %%
# Code Cell 5
# !pip install datasets==3.1.0
# !pip install transformers==4.46.2
########## [TODO] Install packages used in your .py file with specified version ############
# You must only add code below this line, within this cell.
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# Code Cell 6
# change student_id to your student ID

# !python /content/drive/MyDrive/AI504/20233980.py \
--json_path '/content/drive/MyDrive/AI504/instruct_tuning/instruct.json' \
--image_folder_path '/content/drive/MyDrive/AI504/instruct_tuning/images'
# Out:
# 2024-12-17 05:13:45.622300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-17 05:13:45.641540: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-17 05:13:45.647356: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-17 05:13:45.661496: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Code Cell 7
import torch
import os
# Change the current working directory
os.chdir('/content/drive/MyDrive/AI504')

from test_vlm import evaluate

evaluate("20233980.npy",
         '/content/drive/MyDrive/AI504/instruct_tuning/instruct.json',
         '/content/drive/MyDrive/AI504/instruct_tuning/images')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Using device: cpu
# 20233980 - Perplexity: 4
